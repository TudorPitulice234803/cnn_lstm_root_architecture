# %%
from inference import pipeline
from root_measurement import segment_image, measuring_skeleton
import os

models_dir = 'models'
data_dir = 'data_v1_unprocessed/test'
for model in os.listdir(models_dir):
    model_path = os.path.join(models_dir, model)
    pipeline(data_dir, model_path, view_growth=True, view_masks=False)
# Out:
# 2025-11-22 13:51:00.567509: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-22 13:51:00.598839: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-22 13:51:00.598871: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-22 13:51:00.600022: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-22 13:51:00.605800: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-22 13:51:02.697199: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-11-22 13:51:02.698067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46536 MB memory:  -> device: 0, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:01:00.0, compute capability: 8.9
# models/unet_run4.h5
# 2025-11-22 13:51:03.883615: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2/2 [==============================] - 3s 763ms/step
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 12ms/step
# === Average Metrics ===
# Avg F1 Score: 0.6664
# Avg mIoU: 0.5030
# Avg Precision: 0.9481
# Avg Recall: 0.5165
# models/unet_run5.h5
# 2/2 [==============================] - 0s 13ms/step
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 13ms/step
# Error measuring plant 3 in 28_05_03.png: index pointer size 0 should be 1
# 2/2 [==============================] - 0s 13ms/step
# Error measuring plant 3 in 28_05_04.png: index pointer size 0 should be 1
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# === Average Metrics ===
# Avg F1 Score: 0.3031
# Avg mIoU: 0.1787
# Avg Precision: 0.9431
# Avg Recall: 0.1808
# models/unet_run2.h5
# 2/2 [==============================] - 0s 14ms/step
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# === Average Metrics ===
# Avg F1 Score: 0.7433
# Avg mIoU: 0.5924
# Avg Precision: 0.9337
# Avg Recall: 0.6184
# models/unet_run1.h5
# 2/2 [==============================] - 0s 13ms/step
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 14ms/step
# === Average Metrics ===
# Avg F1 Score: 0.6416
# Avg mIoU: 0.4753
# Avg Precision: 0.9460
# Avg Recall: 0.4876
# models/unet_run3.h5
# 2/2 [==============================] - 0s 13ms/step
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 12ms/step
# === Average Metrics ===
# Avg F1 Score: 0.6402
# Avg mIoU: 0.4840
# Avg Precision: 0.9384
# Avg Recall: 0.4962

# %%
import cv2
import numpy as np
import pandas as pd
from patchify import patchify, unpatchify
import keras.backend as K
import tensorflow as tf
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from skimage.morphology import remove_small_objects
from sklearn.metrics import jaccard_score, precision_score, recall_score
from sklearn.metrics import f1_score as f1_metric
import os

from preprocess import crop, padder, crop_to_coordinates
from helpers import f1

def pipeline(image_dir, model_path, kernel_size=5, patch_size=256):
    files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])
    model = load_model(model_path, custom_objects={"f1": f1})
    
    all_f1 = []
    all_iou = []
    all_precision = []
    all_recall = []

    for file in files:
        if file.endswith('.png'):
            # Read and preprocess image
            img_path = os.path.join(image_dir, file)
            image = cv2.imread(img_path, 0)
            image_cropped, stats, centroids = crop(image, kernel_size=kernel_size)
            image_color = cv2.cvtColor(image_cropped, cv2.COLOR_GRAY2RGB)
            image_np = image_color / 255.0

            # Pad and patchify
            image_padded = padder(image_np, patch_size=patch_size)
            patches = patchify(image_padded, (patch_size, patch_size, 3), step=patch_size)
            expected_shape = (image_padded.shape[0] // patch_size, image_padded.shape[1] // patch_size)
            patches = patches.reshape(-1, patch_size, patch_size, 3)

            # Predict
            predicted_patches = model.predict(patches)
            predicted_patches = predicted_patches.reshape(expected_shape[0], expected_shape[1], patch_size, patch_size, predicted_patches.shape[-1])
            predicted_patches = predicted_patches[:, :, :, :, 0]
            prediction = unpatchify(predicted_patches, image_padded.shape[:2])
            prediction_bool = (prediction > 0.5).astype(np.uint8)

            # Load mask
            mask_path = os.path.join(image_dir, file).replace('.png', '.tif')
            if not os.path.exists(mask_path):
                print(f"Mask for {file} not found, skipping...")
                continue
            mask = cv2.imread(mask_path, 0)
            mask = crop_to_coordinates(mask, stats, centroids)
            mask = padder(mask, patch_size=patch_size)
            mask_bool = (mask > 0.5).astype(np.uint8)

            if np.sum(mask_bool) == 0:
                print(f"Skipping {file} - no positive pixels in ground truth")
                continue

            # Calculate metrics
            pred_flat = prediction_bool.flatten()
            mask_flat = mask_bool.flatten()
            
            f1_val = f1_metric(mask_flat, pred_flat)
            iou_val = jaccard_score(mask_flat, pred_flat)
            precision_val = precision_score(mask_flat, pred_flat)
            recall_val = recall_score(mask_flat, pred_flat)

            all_f1.append(f1_val)
            all_iou.append(iou_val)
            all_precision.append(precision_val)
            all_recall.append(recall_val)

            # Display this prediction
            fig, axs = plt.subplots(1, 2, figsize=(15, 5))
            axs[0].imshow(image_np)
            axs[0].set_title(f"{file} - Original")
            axs[0].axis("off")

            axs[1].imshow(prediction_bool, cmap='gray')
            axs[1].set_title(f"Predicted (F1: {f1_val:.3f})")
            axs[1].axis("off")

            plt.tight_layout()
            plt.show()

    # Print averages
    if all_f1:
        print("\n=== Average Metrics ===")
        print(f"F1: {np.mean(all_f1):.4f}")
        print(f"IoU: {np.mean(all_iou):.4f}")
        print(f"Precision: {np.mean(all_precision):.4f}")
        print(f"Recall: {np.mean(all_recall):.4f}")

# %%
image_dir = 'data_v1_unprocessed/test'
model_path = 'models/unet_run3.h5'

pipeline(image_dir, model_path)
# Out:
# 2/2 [==============================] - 0s 70ms/step
# Skipping 28_05_01.png - no positive pixels in ground truth
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 83ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 67ms/step
# === Average Metrics ===
# F1: 0.6402
# IoU: 0.4840
# Precision: 0.9384
# Recall: 0.4962
