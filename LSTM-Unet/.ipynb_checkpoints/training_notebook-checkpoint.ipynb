# %%
from tensorflow.keras.models import Model
import tensorflow as tf
from model import lstm_unet
import keras.backend as K
from helpers import f1
import warnings
import numpy as np
import matplotlib.pyplot as plt
from data_loader import DataGenerator
warnings.filterwarnings("ignore")

gpus = tf.config.list_physical_devices('GPU')
if gpus:
   tf.config.set_visible_devices(gpus[0], 'GPU')
   tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# 2025-08-17 18:04:33.253897: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-17 18:04:33.291058: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-08-17 18:04:33.291094: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-08-17 18:04:33.292438: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-17 18:04:33.299174: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model = lstm_unet()

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[f1])
model.summary()
# Out:
# 2025-08-17 18:04:35.437504: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46672 MB memory:  -> device: 0, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:21:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 15, 256, 256, 3)]    0         []
#
#  time_distributed (TimeDist  (None, 15, 256, 256, 16)     448       ['input_1[0][0]']
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 15, 256, 256, 16)     64        ['time_distributed[0][0]']
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 15, 256, 256, 16)     0         ['time_distributed_1[0][0]']
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 15, 256, 256, 16)     0         ['time_distributed_2[0][0]']
#  stributed)
#
#  time_distributed_4 (TimeDi  (None, 15, 256, 256, 16)     2320      ['time_distributed_3[0][0]']
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 15, 256, 256, 16)     64        ['time_distributed_4[0][0]']
#  stributed)
#
#  time_distributed_6 (TimeDi  (None, 15, 256, 256, 16)     0         ['time_distributed_5[0][0]']
#  stributed)
#
#  time_distributed_7 (TimeDi  (None, 15, 128, 128, 16)     0         ['time_distributed_6[0][0]']
#  stributed)
#
#  time_distributed_8 (TimeDi  (None, 15, 128, 128, 32)     4640      ['time_distributed_7[0][0]']
#  stributed)
#
#  time_distributed_9 (TimeDi  (None, 15, 128, 128, 32)     128       ['time_distributed_8[0][0]']
#  stributed)
#
#  time_distributed_10 (TimeD  (None, 15, 128, 128, 32)     0         ['time_distributed_9[0][0]']
#  istributed)
#
#  time_distributed_11 (TimeD  (None, 15, 128, 128, 32)     0         ['time_distributed_10[0][0]']
#  istributed)
#
#  time_distributed_12 (TimeD  (None, 15, 128, 128, 32)     9248      ['time_distributed_11[0][0]']
#  istributed)
#
#  time_distributed_13 (TimeD  (None, 15, 128, 128, 32)     128       ['time_distributed_12[0][0]']
#  istributed)
#
#  time_distributed_14 (TimeD  (None, 15, 128, 128, 32)     0         ['time_distributed_13[0][0]']
#  istributed)
#
#  time_distributed_15 (TimeD  (None, 15, 64, 64, 32)       0         ['time_distributed_14[0][0]']
#  istributed)
#
#  time_distributed_16 (TimeD  (None, 15, 64, 64, 64)       18496     ['time_distributed_15[0][0]']
#  istributed)
#
#  time_distributed_17 (TimeD  (None, 15, 64, 64, 64)       256       ['time_distributed_16[0][0]']
#  istributed)
#
#  time_distributed_18 (TimeD  (None, 15, 64, 64, 64)       0         ['time_distributed_17[0][0]']
#  istributed)
#
#  time_distributed_19 (TimeD  (None, 15, 64, 64, 64)       0         ['time_distributed_18[0][0]']
#  istributed)
#
#  time_distributed_20 (TimeD  (None, 15, 64, 64, 64)       36928     ['time_distributed_19[0][0]']
#  istributed)
#
#  time_distributed_21 (TimeD  (None, 15, 64, 64, 64)       256       ['time_distributed_20[0][0]']
#  istributed)
#
#  time_distributed_22 (TimeD  (None, 15, 64, 64, 64)       0         ['time_distributed_21[0][0]']
#  istributed)
#
#  time_distributed_23 (TimeD  (None, 15, 32, 32, 64)       0         ['time_distributed_22[0][0]']
#  istributed)
#
#  time_distributed_24 (TimeD  (None, 15, 32, 32, 128)      73856     ['time_distributed_23[0][0]']
#  istributed)
#
#  time_distributed_25 (TimeD  (None, 15, 32, 32, 128)      512       ['time_distributed_24[0][0]']
#  istributed)
#
#  time_distributed_26 (TimeD  (None, 15, 32, 32, 128)      0         ['time_distributed_25[0][0]']
#  istributed)
#
#  time_distributed_27 (TimeD  (None, 15, 32, 32, 128)      0         ['time_distributed_26[0][0]']
#  istributed)
#
#  time_distributed_28 (TimeD  (None, 15, 32, 32, 128)      147584    ['time_distributed_27[0][0]']
#  istributed)
#
#  time_distributed_29 (TimeD  (None, 15, 32, 32, 128)      512       ['time_distributed_28[0][0]']
#  istributed)
#
#  time_distributed_30 (TimeD  (None, 15, 32, 32, 128)      0         ['time_distributed_29[0][0]']
#  istributed)
#
#  time_distributed_31 (TimeD  (None, 15, 16, 16, 128)      0         ['time_distributed_30[0][0]']
#  istributed)
#
#  conv_lstm2d (ConvLSTM2D)    (None, 15, 16, 16, 128)      1180160   ['time_distributed_31[0][0]']
#
#  batch_normalization_8 (Bat  (None, 15, 16, 16, 128)      512       ['conv_lstm2d[0][0]']
#  chNormalization)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, 15, 16, 16, 128)      1180160   ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  batch_normalization_9 (Bat  (None, 15, 16, 16, 128)      512       ['conv_lstm2d_1[0][0]']
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 15, 16, 16, 128)      0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  time_distributed_32 (TimeD  (None, 15, 32, 32, 128)      65664     ['dropout_4[0][0]']
#  istributed)
#
#  time_distributed_33 (TimeD  (None, 15, 32, 32, 128)      512       ['time_distributed_32[0][0]']
#  istributed)
#
#  time_distributed_34 (TimeD  (None, 15, 32, 32, 128)      0         ['time_distributed_33[0][0]']
#  istributed)
#
#  concatenate (Concatenate)   (None, 15, 32, 32, 256)      0         ['time_distributed_34[0][0]',
#                                                                      'time_distributed_30[0][0]']
#
#  time_distributed_35 (TimeD  (None, 15, 32, 32, 128)      295040    ['concatenate[0][0]']
#  istributed)
#
#  time_distributed_36 (TimeD  (None, 15, 32, 32, 128)      512       ['time_distributed_35[0][0]']
#  istributed)
#
#  time_distributed_37 (TimeD  (None, 15, 32, 32, 128)      0         ['time_distributed_36[0][0]']
#  istributed)
#
#  time_distributed_38 (TimeD  (None, 15, 32, 32, 128)      0         ['time_distributed_37[0][0]']
#  istributed)
#
#  time_distributed_39 (TimeD  (None, 15, 32, 32, 128)      147584    ['time_distributed_38[0][0]']
#  istributed)
#
#  time_distributed_40 (TimeD  (None, 15, 32, 32, 128)      512       ['time_distributed_39[0][0]']
#  istributed)
#
#  time_distributed_41 (TimeD  (None, 15, 32, 32, 128)      0         ['time_distributed_40[0][0]']
#  istributed)
#
#  time_distributed_42 (TimeD  (None, 15, 64, 64, 64)       32832     ['time_distributed_41[0][0]']
#  istributed)
#
#  time_distributed_43 (TimeD  (None, 15, 64, 64, 64)       256       ['time_distributed_42[0][0]']
#  istributed)
#
#  time_distributed_44 (TimeD  (None, 15, 64, 64, 64)       0         ['time_distributed_43[0][0]']
#  istributed)
#
#  concatenate_1 (Concatenate  (None, 15, 64, 64, 128)      0         ['time_distributed_44[0][0]',
#  )                                                                   'time_distributed_22[0][0]']
#
#  time_distributed_45 (TimeD  (None, 15, 64, 64, 64)       73792     ['concatenate_1[0][0]']
#  istributed)
#
#  time_distributed_46 (TimeD  (None, 15, 64, 64, 64)       256       ['time_distributed_45[0][0]']
#  istributed)
#
#  time_distributed_47 (TimeD  (None, 15, 64, 64, 64)       0         ['time_distributed_46[0][0]']
#  istributed)
#
#  time_distributed_48 (TimeD  (None, 15, 64, 64, 64)       0         ['time_distributed_47[0][0]']
#  istributed)
#
#  time_distributed_49 (TimeD  (None, 15, 64, 64, 64)       36928     ['time_distributed_48[0][0]']
#  istributed)
#
#  time_distributed_50 (TimeD  (None, 15, 64, 64, 64)       256       ['time_distributed_49[0][0]']
#  istributed)
#
#  time_distributed_51 (TimeD  (None, 15, 64, 64, 64)       0         ['time_distributed_50[0][0]']
#  istributed)
#
#  time_distributed_52 (TimeD  (None, 15, 128, 128, 32)     8224      ['time_distributed_51[0][0]']
#  istributed)
#
#  time_distributed_53 (TimeD  (None, 15, 128, 128, 32)     128       ['time_distributed_52[0][0]']
#  istributed)
#
#  time_distributed_54 (TimeD  (None, 15, 128, 128, 32)     0         ['time_distributed_53[0][0]']
#  istributed)
#
#  concatenate_2 (Concatenate  (None, 15, 128, 128, 64)     0         ['time_distributed_54[0][0]',
#  )                                                                   'time_distributed_14[0][0]']
#
#  time_distributed_55 (TimeD  (None, 15, 128, 128, 32)     18464     ['concatenate_2[0][0]']
#  istributed)
#
#  time_distributed_56 (TimeD  (None, 15, 128, 128, 32)     128       ['time_distributed_55[0][0]']
#  istributed)
#
#  time_distributed_57 (TimeD  (None, 15, 128, 128, 32)     0         ['time_distributed_56[0][0]']
#  istributed)
#
#  time_distributed_58 (TimeD  (None, 15, 128, 128, 32)     0         ['time_distributed_57[0][0]']
#  istributed)
#
#  time_distributed_59 (TimeD  (None, 15, 128, 128, 32)     9248      ['time_distributed_58[0][0]']
#  istributed)
#
#  time_distributed_60 (TimeD  (None, 15, 128, 128, 32)     128       ['time_distributed_59[0][0]']
#  istributed)
#
#  time_distributed_61 (TimeD  (None, 15, 128, 128, 32)     0         ['time_distributed_60[0][0]']
#  istributed)
#
#  time_distributed_62 (TimeD  (None, 15, 256, 256, 16)     2064      ['time_distributed_61[0][0]']
#  istributed)
#
#  time_distributed_63 (TimeD  (None, 15, 256, 256, 16)     64        ['time_distributed_62[0][0]']
#  istributed)
#
#  time_distributed_64 (TimeD  (None, 15, 256, 256, 16)     0         ['time_distributed_63[0][0]']
#  istributed)
#
#  concatenate_3 (Concatenate  (None, 15, 256, 256, 32)     0         ['time_distributed_64[0][0]',
#  )                                                                   'time_distributed_6[0][0]']
#
#  time_distributed_65 (TimeD  (None, 15, 256, 256, 16)     4624      ['concatenate_3[0][0]']
#  istributed)
#
#  time_distributed_66 (TimeD  (None, 15, 256, 256, 16)     64        ['time_distributed_65[0][0]']
#  istributed)
#
#  time_distributed_67 (TimeD  (None, 15, 256, 256, 16)     0         ['time_distributed_66[0][0]']
#  istributed)
#
#  time_distributed_68 (TimeD  (None, 15, 256, 256, 16)     0         ['time_distributed_67[0][0]']
#  istributed)
#
#  time_distributed_69 (TimeD  (None, 15, 256, 256, 16)     2320      ['time_distributed_68[0][0]']
#  istributed)
#
#  time_distributed_70 (TimeD  (None, 15, 256, 256, 16)     64        ['time_distributed_69[0][0]']
#  istributed)
#
#  time_distributed_71 (TimeD  (None, 15, 256, 256, 16)     0         ['time_distributed_70[0][0]']
#  istributed)
#
#  time_distributed_72 (TimeD  (None, 15, 256, 256, 1)      17        ['time_distributed_71[0][0]']
#  istributed)
#
# ==================================================================================================
# Total params: 3356465 (12.80 MB)
# Trainable params: 3353553 (12.79 MB)
# Non-trainable params: 2912 (11.38 KB)
# __________________________________________________________________________________________________

# %%
train_gen = DataGenerator(
    image_dir="../Unet/data_v3_processed/train/images/images",
    mask_dir="../Unet/data_v3_processed/train/masks/masks",
    batch_size=8,
    time_steps=15,
    img_size=(256,256),
    normalize_images=True,
    normalize_masks=False,
    infinite=True,
)

# %%
val_gen = DataGenerator(
    image_dir="../Unet/data_v3_processed/val/images/images",
    mask_dir="../Unet/data_v3_processed/val/masks/masks",
    batch_size=8,
    time_steps=15,
    img_size=(256,256),
    normalize_images=True,
    normalize_masks=False,
    infinite=True
)

# %%
history = model.fit(train_gen,
                    validation_data=val_gen,
                    epochs=1,
                    steps_per_epoch=3000,
                    validation_steps=13)
# Out:
# 2025-08-17 18:04:47.498104: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2025-08-17 18:04:53.474043: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f8ecc36b370 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-08-17 18:04:53.474090: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX 6000 Ada Generation, Compute Capability 8.9
# 2025-08-17 18:04:53.478666: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1755453893.578734  133398 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3000/3000 [==============================] - 1291s 420ms/step - loss: 0.0357 - f1: 0.7499 - val_loss: 0.0088 - val_f1: 0.7053

# %%
model.save("lstm_unet_model.h5")
