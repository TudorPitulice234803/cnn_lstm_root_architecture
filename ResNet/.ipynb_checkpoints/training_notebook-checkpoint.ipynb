# %%
from tensorflow.keras.models import Model
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from model import unet
import keras.backend as K
from helpers import f1
import warnings
import numpy as np
warnings.filterwarnings("ignore")

# %%
model = unet(256, 256, 3)

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[f1])
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  conv2d_76 (Conv2D)          (None, 256, 256, 16)         448       ['input_5[0][0]']
#
#  dropout_36 (Dropout)        (None, 256, 256, 16)         0         ['conv2d_76[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 256, 256, 16)         2320      ['dropout_36[0][0]']
#
#  max_pooling2d_16 (MaxPooli  (None, 128, 128, 16)         0         ['conv2d_77[0][0]']
#  ng2D)
#
#  conv2d_78 (Conv2D)          (None, 128, 128, 32)         4640      ['max_pooling2d_16[0][0]']
#
#  dropout_37 (Dropout)        (None, 128, 128, 32)         0         ['conv2d_78[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 128, 128, 32)         9248      ['dropout_37[0][0]']
#
#  max_pooling2d_17 (MaxPooli  (None, 64, 64, 32)           0         ['conv2d_79[0][0]']
#  ng2D)
#
#  conv2d_80 (Conv2D)          (None, 64, 64, 64)           18496     ['max_pooling2d_17[0][0]']
#
#  dropout_38 (Dropout)        (None, 64, 64, 64)           0         ['conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 64, 64, 64)           36928     ['dropout_38[0][0]']
#
#  max_pooling2d_18 (MaxPooli  (None, 32, 32, 64)           0         ['conv2d_81[0][0]']
#  ng2D)
#
#  conv2d_82 (Conv2D)          (None, 32, 32, 128)          73856     ['max_pooling2d_18[0][0]']
#
#  dropout_39 (Dropout)        (None, 32, 32, 128)          0         ['conv2d_82[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 32, 32, 128)          147584    ['dropout_39[0][0]']
#
#  max_pooling2d_19 (MaxPooli  (None, 16, 16, 128)          0         ['conv2d_83[0][0]']
#  ng2D)
#
#  conv2d_84 (Conv2D)          (None, 16, 16, 256)          295168    ['max_pooling2d_19[0][0]']
#
#  dropout_40 (Dropout)        (None, 16, 16, 256)          0         ['conv2d_84[0][0]']
#
#  conv2d_85 (Conv2D)          (None, 16, 16, 256)          590080    ['dropout_40[0][0]']
#
#  conv2d_transpose_16 (Conv2  (None, 32, 32, 128)          131200    ['conv2d_85[0][0]']
#  DTranspose)
#
#  concatenate_16 (Concatenat  (None, 32, 32, 256)          0         ['conv2d_transpose_16[0][0]',
#  e)                                                                  'conv2d_83[0][0]']
#
#  conv2d_86 (Conv2D)          (None, 32, 32, 128)          295040    ['concatenate_16[0][0]']
#
#  dropout_41 (Dropout)        (None, 32, 32, 128)          0         ['conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 32, 32, 128)          147584    ['dropout_41[0][0]']
#
#  conv2d_transpose_17 (Conv2  (None, 64, 64, 64)           32832     ['conv2d_87[0][0]']
#  DTranspose)
#
#  concatenate_17 (Concatenat  (None, 64, 64, 128)          0         ['conv2d_transpose_17[0][0]',
#  e)                                                                  'conv2d_81[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 64, 64, 64)           73792     ['concatenate_17[0][0]']
#
#  dropout_42 (Dropout)        (None, 64, 64, 64)           0         ['conv2d_88[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 64, 64, 64)           36928     ['dropout_42[0][0]']
#
#  conv2d_transpose_18 (Conv2  (None, 128, 128, 32)         8224      ['conv2d_89[0][0]']
#  DTranspose)
#
#  concatenate_18 (Concatenat  (None, 128, 128, 64)         0         ['conv2d_transpose_18[0][0]',
#  e)                                                                  'conv2d_79[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 128, 128, 32)         18464     ['concatenate_18[0][0]']
#
#  dropout_43 (Dropout)        (None, 128, 128, 32)         0         ['conv2d_90[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 128, 128, 32)         9248      ['dropout_43[0][0]']
#
#  conv2d_transpose_19 (Conv2  (None, 256, 256, 16)         2064      ['conv2d_91[0][0]']
#  DTranspose)
#
#  concatenate_19 (Concatenat  (None, 256, 256, 32)         0         ['conv2d_transpose_19[0][0]',
#  e)                                                                  'conv2d_77[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 256, 256, 16)         4624      ['concatenate_19[0][0]']
#
#  dropout_44 (Dropout)        (None, 256, 256, 16)         0         ['conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 256, 256, 16)         2320      ['dropout_44[0][0]']
#
#  conv2d_94 (Conv2D)          (None, 256, 256, 1)          17        ['conv2d_93[0][0]']
#
# ==================================================================================================
# Total params: 1941105 (7.40 MB)
# Trainable params: 1941105 (7.40 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Images generator (RGB)
train_image_datagen = ImageDataGenerator(rescale=1./255)

train_image_generator = train_image_datagen.flow_from_directory(
    'data_v3_processed/train/images',
    target_size=(256, 256),
    batch_size=8,
    class_mode=None,
    color_mode='rgb',
    seed=42)

# Masks generator (grayscale, single channel)
train_mask_datagen = ImageDataGenerator()

train_mask_generator = train_mask_datagen.flow_from_directory(
    'data_v3_processed/train/masks',
    target_size=(256, 256),
    batch_size=8,
    class_mode=None,
    color_mode='grayscale',
    seed=42)
# Out:
# Found 3285 images belonging to 2 classes.
# Found 3285 images belonging to 2 classes.

# %%
val_image_datagen = ImageDataGenerator(rescale=1./255)

val_image_generator = val_image_datagen.flow_from_directory(
    'data_v3_processed/val/images',
    target_size=(256, 256),
    batch_size=8,
    class_mode=None,
    color_mode='rgb',
    seed=42,
    shuffle = False,)

# Masks generator (grayscale, single channel)
val_mask_datagen = ImageDataGenerator()

val_mask_generator = val_mask_datagen.flow_from_directory(
    'data_v3_processed/val/masks',
    target_size=(256, 256),
    batch_size=8,
    class_mode=None,
    color_mode='grayscale',
    seed=42,
    shuffle = False,)
# Out:
# Found 109 images belonging to 1 classes.
# Found 108 images belonging to 1 classes.

# %%
def combine_generator(image_generator, mask_generator):
    while True:
        for img_batch, mask_batch in zip(image_generator, mask_generator):
            yield img_batch, mask_batch

train_generator = combine_generator(train_image_generator, train_mask_generator)
val_generator = combine_generator(val_image_generator, val_mask_generator)

# %%
history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=1,
                    steps_per_epoch=2000,
                    validation_steps=13)
# Out:
# 2000/2000 [==============================] - 274s 136ms/step - loss: 0.0148 - f1: 0.3991 - val_loss: 0.0151 - val_f1: 0.6814

# %%
import cv2
import numpy as np

img = cv2.imread('data_v3_processed/test/images/images/28_05_08_11.png')
mask = cv2.imread('data_v3_processed/test/masks/masks/28_05_08_11.tif')

img_np = np.array(img)
img_np = np.expand_dims(img_np, axis=0)
img_np = img_np / 255

pred = model.predict(img_np)
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
import matplotlib.pyplot as plt

confidence_map = pred[0, :, :, 0]  # Remove batch and channel dims

plt.imshow(confidence_map, cmap='viridis')
plt.colorbar(label="Model Confidence")
plt.title("Model Confidence per Pixel")
plt.axis('off')
plt.show()

# %%
pred = (pred > 0.5).astype(np.uint8)

pred_img = np.squeeze(pred, axis=0)
pred_vis = (pred_img * 255).astype(np.uint8)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))  # width x height in inches

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img)
plt.title('Image')
plt.axis('off')

# Prediction
plt.subplot(1, 2, 2)
plt.imshow(pred_vis, cmap='gray')
plt.title('Prediction')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
model.save("unet_model.h5")
