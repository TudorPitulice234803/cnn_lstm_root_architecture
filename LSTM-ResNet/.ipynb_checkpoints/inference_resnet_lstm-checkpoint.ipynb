# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from patchify import patchify, unpatchify
from tensorflow.keras.models import load_model
from sklearn.metrics import jaccard_score, precision_score, recall_score
from sklearn.metrics import f1_score as f1_metric
import pandas as pd
from datetime import datetime

from preprocess import crop, padder, crop_to_coordinates
from helpers import f1

def inference_single_model(model, image_dir, time_steps=15, kernel_size=5, patch_size=256):
    """
    Run inference for a single model and return metrics.
    """
    # Load image file names
    files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])
    mask_dir = image_dir

    # Metrics storage
    all_f1, all_iou, all_precision, all_recall = [], [], [], []

    num_sequences = len(files) // time_steps
    for seq_idx in range(num_sequences):
        seq_files = files[seq_idx * time_steps:(seq_idx + 1) * time_steps]
        frames_padded = []
        stats, centroids = None, None

        # Preprocess each frame in the sequence
        for file in seq_files:
            img_path = os.path.join(image_dir, file)
            image = cv2.imread(img_path, 0)  # Grayscale
            image_cropped, stats, centroids = crop(image, kernel_size=kernel_size)
            image_color = cv2.cvtColor(image_cropped, cv2.COLOR_GRAY2RGB)
            image_np = image_color / 255.0
            image_padded = padder(image_np, patch_size=patch_size)
            frames_padded.append(image_padded)

        frames_padded = np.array(frames_padded)  # (time_steps, H, W, 3)
        H, W, _ = frames_padded[0].shape

        # Patchify all frames
        patches_seq = []
        for t in range(time_steps):
            patches = patchify(frames_padded[t], (patch_size, patch_size, 3), step=patch_size)
            patches_seq.append(patches)

        patches_seq = np.stack(patches_seq, axis=2)
        num_x, num_y = patches_seq.shape[:2]

        # Reshape to (num_patches, time_steps, patch_size, patch_size, 3)
        patches_seq = patches_seq.reshape(-1, time_steps, patch_size, patch_size, 3)

        # Predict masks for all time steps
        predicted_patches = model.predict(patches_seq, verbose=0)

        # Reshape back to (num_x, num_y, time_steps, patch_size, patch_size)
        predicted_patches = predicted_patches.reshape(num_x, num_y, time_steps, patch_size, patch_size)

        # Process each frame
        for t in range(time_steps):
            predicted_mask = unpatchify(predicted_patches[:, :, t, :, :], (H, W))
            prediction_bool = (predicted_mask > 0.5).astype(np.uint8)

            # Load corresponding ground truth mask
            mask_filename = seq_files[t].replace('.png', '.tif')
            mask_path = os.path.join(mask_dir, mask_filename)
            if not os.path.exists(mask_path):
                print(f"  Mask for {seq_files[t]} not found, skipping frame...")
                continue

            mask = cv2.imread(mask_path, 0)
            mask = crop_to_coordinates(mask, stats, centroids)
            mask = padder(mask, patch_size=patch_size)
            mask_bool = (mask > 0.5).astype(np.uint8)

            if np.sum(mask_bool) == 0:
                print(f"  Skipping frame {seq_files[t]} as ground truth has no positive pixels.")
                continue

            # Compute metrics
            pred_flat = prediction_bool.flatten()
            mask_flat = mask_bool.flatten()
            f1_val = f1_metric(mask_flat, pred_flat)
            iou_val = jaccard_score(mask_flat, pred_flat)
            precision_val = precision_score(mask_flat, pred_flat, zero_division=0)
            recall_val = recall_score(mask_flat, pred_flat, zero_division=0)

            all_f1.append(f1_val)
            all_iou.append(iou_val)
            all_precision.append(precision_val)
            all_recall.append(recall_val)

    # Calculate average metrics
    metrics = {
        'f1': np.mean(all_f1) if all_f1 else 0.0,
        'iou': np.mean(all_iou) if all_iou else 0.0,
        'precision': np.mean(all_precision) if all_precision else 0.0,
        'recall': np.mean(all_recall) if all_recall else 0.0,
        'num_frames': len(all_f1)
    }
    
    return metrics

def pipeline_all_models(models_dir, image_dir, time_steps=15, kernel_size=5, patch_size=256, 
                       model_extensions=['.h5', '.keras'], save_results=True):
    """
    Run inference on all models in a directory and compile results.
    
    Args:
        models_dir: Directory containing all model files
        image_dir: Directory containing test images
        time_steps: Number of time steps for LSTM models
        kernel_size: Kernel size for preprocessing
        patch_size: Patch size for patchifying
        model_extensions: List of model file extensions to look for
        save_results: Whether to save results to CSV
    
    Returns:
        DataFrame with results for all models
    """
    
    # Find all model files
    model_files = []
    for ext in model_extensions:
        model_files.extend([f for f in os.listdir(models_dir) if f.endswith(ext)])
    
    if not model_files:
        print(f"No model files found in {models_dir} with extensions {model_extensions}")
        return None
    
    print(f"Found {len(model_files)} models to evaluate:")
    for mf in model_files:
        print(f"  - {mf}")
    print("\n" + "="*60 + "\n")
    
    # Store results
    results = []
    
    # Process each model
    for idx, model_file in enumerate(model_files, 1):
        model_path = os.path.join(models_dir, model_file)
        model_name = os.path.splitext(model_file)[0]
        
        try:
            # Load model
            model = load_model(model_path, custom_objects={"f1": f1})
            
            # Run inference
            metrics = inference_single_model(
                model, 
                image_dir, 
                time_steps=time_steps,
                kernel_size=kernel_size,
                patch_size=patch_size
            )
            
            # Add model info to metrics
            metrics['model_name'] = model_name
            metrics['model_file'] = model_file
            
            # Print results for this model
            print(f"\n  Results for {model_name}:")
            print(f"    F1 Score:  {metrics['f1']:.4f}")
            print(f"    mIoU:      {metrics['iou']:.4f}")
            print(f"    Precision: {metrics['precision']:.4f}")
            print(f"    Recall:    {metrics['recall']:.4f}")
            print(f"    Frames:    {metrics['num_frames']}")
            
            results.append(metrics)
            
        except Exception as e:
            print(f"  ERROR processing {model_name}: {str(e)}")
            results.append({
                'model_name': model_name,
                'model_file': model_file,
                'f1': np.nan,
                'iou': np.nan,
                'precision': np.nan,
                'recall': np.nan,
                'num_frames': 0,
                'error': str(e)
            })
        
        print("\n" + "="*60 + "\n")
    
    # Create DataFrame with results
    df_results = pd.DataFrame(results)
    
    # Reorder columns for better readability
    column_order = ['model_name', 'f1', 'iou', 'precision', 'recall', 'num_frames', 'model_file']
    if 'error' in df_results.columns:
        column_order.append('error')
    df_results = df_results[column_order]
    
    # Sort by F1 score (descending)
    df_results = df_results.sort_values('f1', ascending=False)
    
    # Save results if requested
    if save_results:
        timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
        output_file = f"lstm_resnet_results_{timestamp}.csv"
        df_results.to_csv(output_file, index=False)

    
    # Print summary
    print("\n" + "="*60)
    print("SUMMARY OF ALL MODELS")
    print("="*60)
    print(df_results.to_string(index=False))
    
    # Print best performing model
    if not df_results.empty and not df_results['f1'].isna().all():
        best_model = df_results.iloc[0]
        print("\n" + "="*60)
        print(f"  F1 Score:  {best_model['f1']:.4f}")
        print(f"  mIoU:      {best_model['iou']:.4f}")
        print("="*60)
    
    return df_results

# Configuration
MODELS_DIR = "models"  # Directory containing all your trained models
IMAGE_DIR = "../LSTM-Unet/data_v3_processed/test"
TIME_STEPS = 15
KERNEL_SIZE = 5
PATCH_SIZE = 256

# Run inference on all models
results_df = pipeline_all_models(
    models_dir=MODELS_DIR,
    image_dir=IMAGE_DIR,
    time_steps=TIME_STEPS,
    kernel_size=KERNEL_SIZE,
    patch_size=PATCH_SIZE,
    model_extensions=['.h5'],  # Add any other extensions you use
    save_results=True
)
# Out:
# Found 5 models to evaluate:
#   - lstm_resnet_run4.h5
#   - lstm_resnet_run2.h5
#   - lstm_resnet_run5.h5
#   - lstm_resnet_run3.h5
#   - lstm_resnet_run1.h5
#
# ============================================================
#
#   Skipping frame 28_05_01.png as ground truth has no positive pixels.
#
#   Results for lstm_resnet_run4:
#     F1 Score:  0.7612
#     mIoU:      0.6147
#     Precision: 0.9209
#     Recall:    0.6496
#     Frames:    14
#
# ============================================================
#
#   Skipping frame 28_05_01.png as ground truth has no positive pixels.
#
#   Results for lstm_resnet_run2:
#     F1 Score:  0.7641
#     mIoU:      0.6185
#     Precision: 0.9263
#     Recall:    0.6512
#     Frames:    14
#
# ============================================================
#
#   Skipping frame 28_05_01.png as ground truth has no positive pixels.
#
#   Results for lstm_resnet_run5:
#     F1 Score:  0.7337
#     mIoU:      0.5806
#     Precision: 0.9247
#     Recall:    0.6096
#     Frames:    14
#
# ============================================================
# WARNING: 5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efaa0286520> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   Skipping frame 28_05_01.png as ground truth has no positive pixels.
#
#   Results for lstm_resnet_run3:
#     F1 Score:  0.7697
#     mIoU:      0.6258
#     Precision: 0.9217
#     Recall:    0.6618
#     Frames:    14
#
# ============================================================
# WARNING: 6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efa7e3dad40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#   Skipping frame 28_05_01.png as ground truth has no positive pixels.
#
#   Results for lstm_resnet_run1:
#     F1 Score:  0.7475
#     mIoU:      0.5973
#     Precision: 0.9189
#     Recall:    0.6308
#     Frames:    14
#
# ============================================================
#
#
# ============================================================
# SUMMARY OF ALL MODELS
# ============================================================
#       model_name       f1      iou  precision   recall  num_frames          model_file
# lstm_resnet_run3 0.769740 0.625827   0.921734 0.661810          14 lstm_resnet_run3.h5
# lstm_resnet_run2 0.764074 0.618465   0.926329 0.651178          14 lstm_resnet_run2.h5
# lstm_resnet_run4 0.761221 0.614664   0.920950 0.649579          14 lstm_resnet_run4.h5
# lstm_resnet_run1 0.747466 0.597330   0.918860 0.630757          14 lstm_resnet_run1.h5
# lstm_resnet_run5 0.733734 0.580609   0.924726 0.609585          14 lstm_resnet_run5.h5
#
# ============================================================
#   F1 Score:  0.7697
#   mIoU:      0.6258
# ============================================================

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from patchify import patchify, unpatchify
from tensorflow.keras.models import load_model
from sklearn.metrics import jaccard_score, precision_score, recall_score
from sklearn.metrics import f1_score as f1_metric
import pandas as pd
from datetime import datetime

from preprocess import crop, padder, crop_to_coordinates
from helpers import f1

def inference_single_model(model, image_dir, time_steps=15, kernel_size=5, patch_size=256):
    """
    Run inference for a single model and return metrics.
    """
    # Load image file names
    files = sorted([f for f in os.listdir(image_dir) if f.endswith('.png')])
    mask_dir = image_dir
    # Metrics storage
    all_f1, all_iou, all_precision, all_recall = [], [], [], []
    num_sequences = len(files) // time_steps
    for seq_idx in range(num_sequences):
        seq_files = files[seq_idx * time_steps:(seq_idx + 1) * time_steps]
        frames_padded = []
        frames_original = []  # Store original images for display
        stats, centroids = None, None
        # Preprocess each frame in the sequence
        for file in seq_files:
            img_path = os.path.join(image_dir, file)
            image = cv2.imread(img_path, 0)  # Grayscale
            image_cropped, stats, centroids = crop(image, kernel_size=kernel_size)
            image_color = cv2.cvtColor(image_cropped, cv2.COLOR_GRAY2RGB)
            image_np = image_color / 255.0
            frames_original.append(image_np)  # Save for display
            image_padded = padder(image_np, patch_size=patch_size)
            frames_padded.append(image_padded)
        frames_padded = np.array(frames_padded)  # (time_steps, H, W, 3)
        H, W, _ = frames_padded[0].shape
        # Patchify all frames
        patches_seq = []
        for t in range(time_steps):
            patches = patchify(frames_padded[t], (patch_size, patch_size, 3), step=patch_size)
            patches_seq.append(patches)
        patches_seq = np.stack(patches_seq, axis=2)
        num_x, num_y = patches_seq.shape[:2]
        # Reshape to (num_patches, time_steps, patch_size, patch_size, 3)
        patches_seq = patches_seq.reshape(-1, time_steps, patch_size, patch_size, 3)
        # Predict masks for all time steps
        predicted_patches = model.predict(patches_seq, verbose=0)
        # Reshape back to (num_x, num_y, time_steps, patch_size, patch_size)
        predicted_patches = predicted_patches.reshape(num_x, num_y, time_steps, patch_size, patch_size)
        # Process each frame
        for t in range(time_steps):
            predicted_mask = unpatchify(predicted_patches[:, :, t, :, :], (H, W))
            prediction_bool = (predicted_mask > 0.5).astype(np.uint8)
            # Load corresponding ground truth mask
            mask_filename = seq_files[t].replace('.png', '.tif')
            mask_path = os.path.join(mask_dir, mask_filename)
            if not os.path.exists(mask_path):
                print(f"  Mask for {seq_files[t]} not found, skipping frame...")
                continue
            mask = cv2.imread(mask_path, 0)
            mask = crop_to_coordinates(mask, stats, centroids)
            mask = padder(mask, patch_size=patch_size)
            mask_bool = (mask > 0.5).astype(np.uint8)
            if np.sum(mask_bool) == 0:
                print(f"  Skipping frame {seq_files[t]} as ground truth has no positive pixels.")
                continue
            # Compute metrics
            pred_flat = prediction_bool.flatten()
            mask_flat = mask_bool.flatten()
            f1_val = f1_metric(mask_flat, pred_flat)
            iou_val = jaccard_score(mask_flat, pred_flat)
            precision_val = precision_score(mask_flat, pred_flat, zero_division=0)
            recall_val = recall_score(mask_flat, pred_flat, zero_division=0)
            all_f1.append(f1_val)
            all_iou.append(iou_val)
            all_precision.append(precision_val)
            all_recall.append(recall_val)
            
            # Display prediction
            fig, axs = plt.subplots(1, 2, figsize=(15, 5))
            axs[0].imshow(frames_original[t])
            axs[0].set_title(f"{seq_files[t]} - Original")
            axs[0].axis("off")

            axs[1].imshow(prediction_bool, cmap='gray')
            axs[1].set_title(f"Predicted (F1: {f1_val:.3f})")
            axs[1].axis("off")

            plt.tight_layout()
            plt.show()
    
    # Calculate average metrics
    metrics = {
        'f1': np.mean(all_f1) if all_f1 else 0.0,
        'iou': np.mean(all_iou) if all_iou else 0.0,
        'precision': np.mean(all_precision) if all_precision else 0.0,
        'recall': np.mean(all_recall) if all_recall else 0.0,
        'num_frames': len(all_f1)
    }
    
    return metrics

model_path = 'models/lstm_resnet_run1.h5'
image_dir = "../LSTM-Unet/data_v3_processed/test"

model = load_model(model_path, custom_objects={"f1": f1})

metrics = inference_single_model(model, image_dir, time_steps=15, kernel_size=5, patch_size=256)

print(metrics)
# Out:
# 2025-10-22 14:55:48.424275: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2025-10-22 14:55:48.424305: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:129] retrieving CUDA diagnostic information for host: a6fac06d5a7e
# 2025-10-22 14:55:48.424318: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:136] hostname: a6fac06d5a7e
# 2025-10-22 14:55:48.424380: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:159] libcuda reported version is: 580.95.5
# 2025-10-22 14:55:48.424405: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:163] kernel reported version is: 580.95.5
# 2025-10-22 14:55:48.424411: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:241] kernel version seems to match DSO: 580.95.5
#   Skipping frame 28_05_01.png as ground truth has no positive pixels.
# {'f1': 0.7474536611475047, 'iou': 0.5973127086942671, 'precision': 0.9188552557643058, 'recall': 0.6307408454986033, 'num_frames': 14}

# %%
# single image inference with same image copied across sequence
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from patchify import patchify, unpatchify
from tensorflow.keras.models import load_model
from sklearn.metrics import jaccard_score, precision_score, recall_score
from sklearn.metrics import f1_score as f1_metric
import pandas as pd
from datetime import datetime

from preprocess import crop, padder, crop_to_coordinates
from helpers import f1

def inference_single_image(model, image_path, time_steps=15, kernel_size=5, patch_size=256):
    """
    Run inference on a single image by repeating it for the full sequence.
    """
    # Read and preprocess the single image
    image = cv2.imread(image_path, 0)  # Grayscale
    image_cropped, stats, centroids = crop(image, kernel_size=kernel_size)
    image_color = cv2.cvtColor(image_cropped, cv2.COLOR_GRAY2RGB)
    image_np = image_color / 255.0
    image_padded = padder(image_np, patch_size=patch_size)
    
    # Repeat the same frame for all time steps
    frames_padded = np.array([image_padded] * time_steps)  # (time_steps, H, W, 3)
    H, W, _ = frames_padded[0].shape
    
    # Patchify all frames
    patches_seq = []
    for t in range(time_steps):
        patches = patchify(frames_padded[t], (patch_size, patch_size, 3), step=patch_size)
        patches_seq.append(patches)
    patches_seq = np.stack(patches_seq, axis=2)
    num_x, num_y = patches_seq.shape[:2]
    
    # Reshape to (num_patches, time_steps, patch_size, patch_size, 3)
    patches_seq = patches_seq.reshape(-1, time_steps, patch_size, patch_size, 3)
    
    # Predict masks for all time steps
    predicted_patches = model.predict(patches_seq, verbose=0)
    
    # Reshape back and get the last time step prediction
    predicted_patches = predicted_patches.reshape(num_x, num_y, time_steps, patch_size, patch_size)
    predicted_mask = unpatchify(predicted_patches[:, :, -1, :, :], (H, W))  # Use last frame
    prediction_bool = (predicted_mask > 0.5).astype(np.uint8)
    
    # Load ground truth mask
    mask_path = image_path.replace('.png', '.tif')
    if os.path.exists(mask_path):
        mask = cv2.imread(mask_path, 0)
        mask = crop_to_coordinates(mask, stats, centroids)
        mask = padder(mask, patch_size=patch_size)
        mask_bool = (mask > 0.5).astype(np.uint8)
        
        # Compute metrics
        pred_flat = prediction_bool.flatten()
        mask_flat = mask_bool.flatten()
        f1_val = f1_metric(mask_flat, pred_flat)
        iou_val = jaccard_score(mask_flat, pred_flat)
        precision_val = precision_score(mask_flat, pred_flat, zero_division=0)
        recall_val = recall_score(mask_flat, pred_flat, zero_division=0)
        
        # Display
        fig, axs = plt.subplots(1, 2, figsize=(15, 5))
        axs[0].imshow(image_np)
        axs[0].set_title(f"Original")
        axs[0].axis("off")
        
        axs[1].imshow(prediction_bool, cmap='gray')
        axs[1].set_title(f"Predicted (F1: {f1_val:.3f})")
        axs[1].axis("off")
        
        return {
            'f1': f1_val,
            'iou': iou_val,
            'precision': precision_val,
            'recall': recall_val
        }
    else:
        # Just display prediction without metrics
        fig, axs = plt.subplots(1, 2, figsize=(10, 5))
        axs[0].imshow(image_np)
        axs[0].set_title("Original")
        axs[0].axis("off")
        
        axs[1].imshow(prediction_bool, cmap='gray')
        axs[1].set_title("Predicted")
        axs[1].axis("off")
        
        plt.tight_layout()
        plt.show()
        
        return None

# Usage
model_path = 'models/lstm_resnet_run1.h5'
image_path = "../LSTM-Unet/data_v3_processed/test/28_05_15.png"

model = load_model(model_path, custom_objects={"f1": f1})
metrics = inference_single_image(model, image_path, time_steps=15)
print(metrics)
# Out:
# 2025-10-24 11:25:04.862933: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-24 11:25:04.992302: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-24 11:25:04.992356: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-24 11:25:05.006682: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-24 11:25:05.045082: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-24 11:25:09.136183: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-10-24 11:25:09.138167: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46549 MB memory:  -> device: 0, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:e1:00.0, compute capability: 8.9
# 2025-10-24 11:25:12.945878: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2025-10-24 11:25:25.927352: W tensorflow/core/kernels/gpu_utils.cc:54] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# {'f1': 0.6167292502913375, 'iou': 0.44584854441636246, 'precision': 0.9214548268523892, 'recall': 0.4634620998345821}

# %%
# Single image inference with black padding

def inference_single_image(model, image_path, time_steps=15, kernel_size=5, patch_size=256):
    """
    Run inference on a single image by padding with black frames and placing the image last.
    """
    # Read and preprocess the single image
    image = cv2.imread(image_path, 0)  # Grayscale
    image_cropped, stats, centroids = crop(image, kernel_size=kernel_size)
    image_color = cv2.cvtColor(image_cropped, cv2.COLOR_GRAY2RGB)
    image_np = image_color / 255.0
    image_padded = padder(image_np, patch_size=patch_size)
    
    # Create black frames for padding (time_steps - 1 black frames + 1 actual image)
    H, W, C = image_padded.shape
    black_frame = np.zeros((H, W, C), dtype=np.float32)
    
    # Build sequence: all black except last frame
    frames_padded = [black_frame] * (time_steps - 1) + [image_padded]
    frames_padded = np.array(frames_padded)  # (time_steps, H, W, 3)
    
    # Patchify all frames
    patches_seq = []
    for t in range(time_steps):
        patches = patchify(frames_padded[t], (patch_size, patch_size, 3), step=patch_size)
        patches_seq.append(patches)
    patches_seq = np.stack(patches_seq, axis=2)
    num_x, num_y = patches_seq.shape[:2]
    
    # Reshape to (num_patches, time_steps, patch_size, patch_size, 3)
    patches_seq = patches_seq.reshape(-1, time_steps, patch_size, patch_size, 3)
    
    # Predict masks for all time steps
    predicted_patches = model.predict(patches_seq, verbose=0)
    
    # Reshape back and get the last time step prediction
    predicted_patches = predicted_patches.reshape(num_x, num_y, time_steps, patch_size, patch_size)
    predicted_mask = unpatchify(predicted_patches[:, :, -1, :, :], (H, W))  # Use last frame
    prediction_bool = (predicted_mask > 0.5).astype(np.uint8)
    
    # Load ground truth mask
    mask_path = image_path.replace('.png', '.tif')
    if os.path.exists(mask_path):
        mask = cv2.imread(mask_path, 0)
        mask = crop_to_coordinates(mask, stats, centroids)
        mask = padder(mask, patch_size=patch_size)
        mask_bool = (mask > 0.5).astype(np.uint8)
        
        # Compute metrics
        pred_flat = prediction_bool.flatten()
        mask_flat = mask_bool.flatten()
        f1_val = f1_metric(mask_flat, pred_flat)
        iou_val = jaccard_score(mask_flat, pred_flat)
        precision_val = precision_score(mask_flat, pred_flat, zero_division=0)
        recall_val = recall_score(mask_flat, pred_flat, zero_division=0)
        
        # Display
        fig, axs = plt.subplots(1, 2, figsize=(15, 5))
        axs[0].imshow(image_np)
        axs[0].set_title(f"Original")
        axs[0].axis("off")
        
        axs[1].imshow(prediction_bool, cmap='gray')
        axs[1].set_title(f"Predicted (F1: {f1_val:.3f})")
        axs[1].axis("off")
        
        plt.tight_layout()
        plt.show()
        
        return {
            'f1': f1_val,
            'iou': iou_val,
            'precision': precision_val,
            'recall': recall_val
        }
    else:
        # Just display prediction without metrics
        fig, axs = plt.subplots(1, 2, figsize=(10, 5))
        axs[0].imshow(image_np)
        axs[0].set_title("Original")
        axs[0].axis("off")
        
        axs[1].imshow(prediction_bool, cmap='gray')
        axs[1].set_title("Predicted")
        axs[1].axis("off")
        
        plt.tight_layout()
        plt.show()
        
        return None

model_path = 'models/lstm_resnet_run1.h5'
image_path = "../LSTM-Unet/data_v3_processed/test/28_05_15.png"

model = load_model(model_path, custom_objects={"f1": f1})
metrics = inference_single_image(model, image_path, time_steps=15)
print(metrics)
# Out:
# {'f1': 0.6201362796917786, 'iou': 0.44941849732324163, 'precision': 0.8973461113158865, 'recall': 0.4737763938892673}

# %%
### Getting line plot for length of primary root
from inference import pipeline
import os
from tensorflow.keras.models import load_model
from helpers import f1

# Configuration
MODELS_DIR = "models"  # Directory containing all your trained models
IMAGE_DIR = "../Unet/data_v1_unprocessed/test"
TIME_STEPS = 15
KERNEL_SIZE = 5
PATCH_SIZE = 256

# Run inference on all models
results_df = pipeline(
    models_dir=MODELS_DIR,
    image_dir=IMAGE_DIR,
    time_steps=TIME_STEPS,
    kernel_size=KERNEL_SIZE,
    patch_size=PATCH_SIZE,
    model_extensions=['.h5'],  # Add any other extensions you use
    save_results=False,
    view_masks=False,
    view_growth=True
)
# Out:
# 2025-11-22 14:10:20.456457: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-22 14:10:20.487044: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-22 14:10:20.487076: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-22 14:10:20.488222: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-22 14:10:20.493801: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 5 models to evaluate:
#   - lstm_resnet_run4.h5
#   - lstm_resnet_run2.h5
#   - lstm_resnet_run5.h5
#   - lstm_resnet_run3.h5
#   - lstm_resnet_run1.h5
#
# ============================================================
#
# Processing model 1/5: lstm_resnet_run4
# 2025-11-22 14:10:22.567824: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-11-22 14:10:22.568792: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46536 MB memory:  -> device: 0, name: NVIDIA RTX 6000 Ada Generation, pci bus id: 0000:e1:00.0, compute capability: 8.9
# 2025-11-22 14:10:26.530666: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# 2025-11-22 14:10:38.762643: W tensorflow/core/kernels/gpu_utils.cc:54] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# === Average Metrics ===
# Avg F1 Score: 0.7612
# Avg mIoU: 0.6147
# Avg Precision: 0.9209
# Avg Recall: 0.6496
#   Results for lstm_resnet_run4:
#     F1 Score:  0.7612
#     mIoU:      0.6147
#     Precision: 0.9209
#     Recall:    0.6496
#     Frames:    14
#
# ============================================================
#
# Processing model 2/5: lstm_resnet_run2
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# === Average Metrics ===
# Avg F1 Score: 0.7641
# Avg mIoU: 0.6185
# Avg Precision: 0.9263
# Avg Recall: 0.6512
#   Results for lstm_resnet_run2:
#     F1 Score:  0.7641
#     mIoU:      0.6185
#     Precision: 0.9263
#     Recall:    0.6512
#     Frames:    14
#
# ============================================================
#
# Processing model 3/5: lstm_resnet_run5
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# === Average Metrics ===
# Avg F1 Score: 0.7337
# Avg mIoU: 0.5806
# Avg Precision: 0.9247
# Avg Recall: 0.6096
#   Results for lstm_resnet_run5:
#     F1 Score:  0.7337
#     mIoU:      0.5806
#     Precision: 0.9247
#     Recall:    0.6096
#     Frames:    14
#
# ============================================================
#
# Processing model 4/5: lstm_resnet_run3
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# === Average Metrics ===
# Avg F1 Score: 0.7697
# Avg mIoU: 0.6258
# Avg Precision: 0.9217
# Avg Recall: 0.6618
#   Results for lstm_resnet_run3:
#     F1 Score:  0.7697
#     mIoU:      0.6258
#     Precision: 0.9217
#     Recall:    0.6618
#     Frames:    14
#
# ============================================================
#
# Processing model 5/5: lstm_resnet_run1
# WARNING: 5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f7339494cc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Skipping frame 28_05_01.png as ground truth has no positive pixels.
# === Average Metrics ===
# Avg F1 Score: 0.7475
# Avg mIoU: 0.5973
# Avg Precision: 0.9189
# Avg Recall: 0.6308
#   Results for lstm_resnet_run1:
#     F1 Score:  0.7475
#     mIoU:      0.5973
#     Precision: 0.9189
#     Recall:    0.6308
#     Frames:    14
#
# ============================================================
#
#
# ============================================================
# SUMMARY OF ALL MODELS
# ============================================================
#       model_name       f1      iou  precision   recall  num_frames          model_file
# lstm_resnet_run3 0.769740 0.625827   0.921734 0.661810          14 lstm_resnet_run3.h5
# lstm_resnet_run2 0.764074 0.618465   0.926329 0.651178          14 lstm_resnet_run2.h5
# lstm_resnet_run4 0.761221 0.614664   0.920950 0.649579          14 lstm_resnet_run4.h5
# lstm_resnet_run1 0.747466 0.597330   0.918860 0.630757          14 lstm_resnet_run1.h5
# lstm_resnet_run5 0.733734 0.580609   0.924726 0.609585          14 lstm_resnet_run5.h5
#
# ============================================================
# BEST MODEL: lstm_resnet_run3
#   F1 Score:  0.7697
#   mIoU:      0.6258
# ============================================================
